# %%
import re
import csv
import math
import json
import numpy as np
import pandas as pd
import pickle
import requests
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import lyricsgenius
genius_TOKEN = 'sD0C3epnJdfOQQK4eIC45dHl-Qv7DipToGpuj1n4WeuG5_LDP1HKn31w5Cn1lOux'
genius = lyricsgenius.Genius(genius_TOKEN)
genius.verbose = False
genius.remove_section_headers = True

# %%
movies = pd.read_csv('merged_data.csv')

# %%
def listify(df):
    genres = []
    languages = []
    countries = []
    for x,y,z in zip(df['Genres'],df['Languages'],df['Countries']):
        g = re.findall(': \"(.*?)\"', x)
        l = re.findall(': \"(.*?)\"', y)
        c = re.findall(': \"(.*?)\"', z)
        genres.append(g)
        languages.append(l)
        countries.append(c)
    df['Genres'] = genres
    df['Languages'] = languages
    df['Countries'] = countries

# %%
listify(movies)

# %%
vectorizer = TfidfVectorizer(max_features=50000, max_df=0.8, min_df=20, norm='l2')
tokenizer = vectorizer.build_tokenizer()

# %%
movies['toks'] = [tokenizer(summary) for summary in movies['Summary']]

# %%
#is_english = ['English Language' in m for m in movies['Languages']]
#movies = movies[is_english]

# %%
'''years = []
for x in movies['ReleaseDate']:
    x = str(x)[:4]
    if x != 'nan':
        years.append(int(x))
    else:
        years.append(3000)
movies['ReleaseDate'] = years'''
# Out:
# "years = []\nfor x in movies['ReleaseDate']:\n    x = str(x)[:4]\n    if x != 'nan':\n        years.append(int(x))\n    else:\n        years.append(3000)\nmovies['ReleaseDate'] = years"

# %%
#movies = movies[movies['ReleaseDate']>=1960]

# %%
#movies = movies.reset_index()
#movies = movies.drop(['index'], axis=1)

# %%
movies.head()
# Out:
#      WikiID                      Title ReleaseDate  Runtime  \
# 0    975900             Ghosts of Mars  2001-08-24     98.0
# 1   9363483           White Of The Eye        1987    110.0
# 2    261236          A Woman in Flames        1983    106.0
# 3  18998739  The Sorcerer's Apprentice        2002     86.0
# 4   6631279                Little city  1997-04-04     93.0
#
#             Languages                   Countries  \
# 0  [English Language]  [United States of America]
# 1  [English Language]            [United Kingdom]
# 2   [German Language]                   [Germany]
# 3  [English Language]              [South Africa]
# 4  [English Language]  [United States of America]
#
#                                               Genres  \
# 0  [Thriller, Science Fiction, Horror, Adventure,...
# 1  [Thriller, Erotic thriller, Psychological thri...
# 2                                            [Drama]
# 3    [Family Film, Fantasy, Adventure, World cinema]
# 4  [Romantic comedy, Ensemble Film, Comedy-drama,...
#
#                                              Summary  compound    pos    neg  \
# 0  Set in the second half of the 22nd century, th...   -0.9913  0.065  0.150
# 1  A series of murders of rich young women throug...   -0.9985  0.078  0.198
# 2  Eva, an upper class housewife, becomes frustra...    0.9604  0.100  0.065
# 3  Every hundred years, the evil Morgana  returns...   -0.8885  0.092  0.131
# 4  Adam, a San Francisco-based artist who works a...   -0.7097  0.089  0.108
#
#      neu                                               toks
# 0  0.786  [Set, in, the, second, half, of, the, 22nd, ce...
# 1  0.724  [series, of, murders, of, rich, young, women, ...
# 2  0.835  [Eva, an, upper, class, housewife, becomes, fr...
# 3  0.776  [Every, hundred, years, the, evil, Morgana, re...
# 4  0.804  [Adam, San, Francisco, based, artist, who, wor...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
s = genius.search_song('XO','eden')
x = analyzer.polarity_scores(s.lyrics)
x1 = x['pos']
y1 = x['neg']

# %%
dist = []
for x2,y2 in tuple(zip(movies['pos'], movies['neg'])):
    dist.append(math.sqrt((x1 - x2)**2 + (y1 - y2)**2))

# %%
dist
# Out:
# [0.09241753080449618,
#  0.11936498649101421,
#  0.050606323715519985,
#  0.059405386961116594,
#  0.05239274758971895,
#  0.09859513172565874,
#  0.08438009243891596,
#  0.05331041174104737,
#  0.03401470270338992,
#  0.03945883931389774,
#  0.07006425622241343,
#  0.03383784863137725,
#  0.11596551211459381,
#  0.0426380112106557,
#  0.05408326913195985,
#  0.0623698645180507,
#  0.05020956084253279,
#  0.0340147027033899,
#  0.13064838307457158,
#  0.0891571646027396,
#  0.11475626344561767,
#  0.14812494725737457,
#  0.09860020283954796,
#  0.08637129152675674,
#  0.10536128321162382,
#  0.03981205847478877,
#  0.04318564576337839,
#  0.09600520819205591,
#  0.0653069674690228,
#  0.09618731725128839,
#  0.04965883607174053,
#  0.056222771187482395,
#  0.11610770861575043,
#  0.0532541078227774,
#  0.1103177229641729,
#  0.1466594695203825,
#  0.065,
#  0.01019803902718558,
#  0.1894333655932872,
#  0.11335784048754635,
#  0.04404543109109049,
#  0.10890821823902916,
#  0.030805843601498725,
#  0.14012851244482688,
#  0.084154619599877,
#  0.05700877125495691,
#  0.084717176534632,
#  0.09024965373894794,
#  0.05643580423808986,
#  0.14675149062275314,
#  0.043416586692184844,
#  0.09257429448826494,
#  0.1110045044131093,
#  0.12531959144523255,
#  0.09841239759298623,
#  0.16378339354159202,
#  0.1048045800525912,
#  0.05464430436925701,
#  0.12776932339180638,
#  0.13004999038831183,
#  0.10973149046650192,
#  0.05024937810560445,
#  0.058830264320330915,
#  0.05663920903402521,
#  0.16975276139138357,
#  0.09604686356149274,
#  0.0510098029794274,
#  0.09684007434941386,
#  0.054378304497290086,
#  0.1070046727951635,
#  0.024041630560342607,
#  0.07907591289387686,
#  0.10647065323364933,
#  0.10530906893520615,
#  0.024698178070456947,
#  0.14187670703818864,
#  0.11049434374663711,
#  0.034525353003264155,
#  0.05821511831131156,
#  0.141718029904455,
#  0.0422018956920184,
#  0.033241540277189334,
#  0.025612496949731407,
#  0.12021647141718976,
#  0.07017834423809101,
#  0.31880401503117867,
#  0.13185598204101323,
#  0.1120044641967453,
#  0.09368030742904296,
#  0.004123105625617665,
#  0.06356099432828284,
#  0.12044085685513867,
#  0.03059411708155671,
#  0.10959014554237988,
#  0.09902019995940224,
#  0.1672632655426768,
#  0.13017296186228539,
#  0.02325940669922601,
#  0.11921828718783038,
#  0.08028075734570521,
#  0.09859513172565877,
#  0.09433981132056604,
#  0.10060318086422516,
#  0.022022715545545236,
#  0.10980892495603445,
#  0.14043147795277242,
#  0.07543208866258445,
#  0.013038404810405283,
#  0.11676472069936192,
#  0.04341658669218483,
#  0.21705759604307795,
#  0.054571054598569015,
#  0.10454664030948099,
#  0.005830951894845282,
#  0.10159724405711015,
#  0.026172504656604815,
#  0.07564390259630979,
#  0.05124451190127581,
#  0.15211837495845135,
#  0.07060453243241542,
#  0.05780138406647371,
#  0.1172006825918689,
#  0.07158910531638178,
#  0.11669190203266033,
#  0.07060453243241542,
#  0.09929753269845128,
#  0.05994163828258285,
#  0.07919595949289332,
#  0.07800640999302559,
#  0.08099382692526635,
#  0.1560288434873501,
#  0.10733592129385205,
#  0.11354734695271397,
#  0.07636753236814714,
#  0.09708243919473801,
#  0.08354639429682169,
#  0.014866068747318509,
#  0.06815423684555495,
#  0.06412487816752559,
#  0.06268173577685929,
#  0.14028898745090437,
#  0.04522167621838008,
#  0.13159027319676783,
#  0.06902897942168928,
#  0.08377350416450301,
#  0.01746424919657297,
#  0.054332310828824525,
#  0.06082762530298222,
#  0.07547184905645284,
#  0.07692203845452876,
#  0.07299315036357865,
#  0.09353608929178085,
#  0.07632168761236877,
#  0.08919641248391105,
#  0.04770744176750623,
#  0.09992497185388646,
#  0.09541488353501253,
#  0.14778700890132396,
#  0.054561891462814975,
#  0.09871676655968833,
#  0.05693856338194705,
#  0.1072054103112338,
#  0.2769855591903665,
#  0.11447707194019248,
#  0.0797621464104371,
#  0.05780138406647371,
#  0.050328918128646476,
#  0.0707248188403477,
#  0.09200543462209174,
#  0.04060788100849391,
#  0.05044799302251777,
#  0.10638138934982944,
#  0.06830812543175226,
#  0.1810331461362808,
#  0.07840918313565062,
#  0.04609772228646445,
#  0.0971648084442099,
#  0.08612781200053791,
#  0.09708243919473801,
#  0.06637017402418048,
#  0.09687620966986683,
#  0.12010412149464314,
#  0.11772000679578642,
#  0.030413812651491113,
#  0.14361058456812995,
#  0.09618731725128839,
#  0.07569015788066505,
#  0.05470831746635974,
#  0.10632027088001612,
#  0.1015135458941318,
#  0.113017697729161,
#  0.06107372593840989,
#  0.04939635614091388,
#  0.06685057965343308,
#  0.1018724692937204,
#  0.11029052543169791,
#  0.08300602387778855,
#  0.1409113196304683,
#  0.08692525524840294,
#  0.14108862463005303,
#  0.05664803615307418,
#  0.100687635785135,
#  0.05408326913195985,
#  0.10123734488813899,
#  0.07513321502504736,
#  0.08759566199304622,
#  0.06203224967708331,
#  0.06835202996254025,
#  0.03220248437620924,
#  0.04554119014694281,
#  0.03569313659514949,
#  0.07034912934784623,
#  0.04104875150354759,
#  0.07912016177940993,
#  0.08900000000000001,
#  0.04827007354458868,
#  0.11907980517283358,
#  0.12006664815842909,
#  0.04609772228646445,
#  0.12065239326262867,
#  0.18987364219396016,
#  0.11732433677630572,
#  0.10184301645179213,
#  0.08154140052758477,
#  0.10543718509140881,
#  0.07333484846919643,
#  0.06859300255857007,
#  0.08839117603018978,
#  0.19076687343456675,
#  0.25292686690029587,
#  0.14060227594174995,
#  0.04272001872658767,
#  0.052630789467763076,
#  0.1051094667477673,
#  0.091706052144883,
#  0.049244289008980514,
#  0.05608029957123982,
#  0.1106932698947863,
#  0.1283900307656323,
#  0.1958800653461194,
#  0.04589117562233505,
#  0.051107729356722566,
#  0.10332473082471591,
#  0.06606814663663572,
#  0.12364869590901474,
#  0.08500000000000002,
#  0.03298484500494128,
#  0.1076289923765897,
#  0.11710678887237924,
#  0.149,
#  0.13147243057006286,
#  0.04382921400162225,
#  0.13152946437965904,
#  0.1217579566188592,
#  0.04600000000000001,
#  0.11907980517283358,
#  0.04527692569068711,
#  0.0782304288624318,
#  0.10489041900955494,
#  0.1294488315899375,
#  0.0839344982709732,
#  0.10269371937952192,
#  0.06844705983459043,
#  0.029068883707497273,
#  0.11822859214251011,
#  0.016643316977093238,
#  0.09861541461658012,
#  0.1415662389130968,
#  0.02300000000000002,
#  0.08558621384311844,
#  0.12628935030318272,
#  0.038209946349085616,
#  0.027658633371878665,
#  0.06841052550594831,
#  0.0662419806467168,
#  0.11881077392223316,
#  0.0356931365951495,
#  0.042154477816715975,
#  0.07984985911070851,
#  0.06500769185258005,
#  0.04019950248448357,
#  0.09492101980067431,
#  0.08324061508662706,
#  0.05371219600798316,
#  0.04560701700396553,
#  0.07169379331573969,
#  0.08185963596303128,
#  0.08477027781009099,
#  0.1805436235373601,
#  0.05408326913195986,
#  0.11806777714516352,
#  0.11704699910719625,
#  0.11043550153822822,
#  0.038275318418009276,
#  0.03807886552931954,
#  0.14430869689661813,
#  0.027294688127912373,
#  0.08958794561770017,
#  0.17497714136423648,
#  0.07963039620647384,
#  0.07595393340703299,
#  0.09013878188659975,
#  0.10822661410207753,
#  0.06251399843235114,
#  0.05554277630799525,
#  0.14286357128393506,
#  0.11387712676389408,
#  0.08709190547921203,
#  0.12901550294441363,
#  0.04080441152620633,
#  0.02720294101747087,
#  0.09047098982546838,
#  0.0778973683766018,
#  0.07038465741907107,
#  0.04085339643163101,
#  0.08099382692526634,
#  0.11211155159036915,
#  0.11754573577973808,
#  0.14900335566691106,
#  0.0266270539113887,
#  0.0967470929795826,
#  0.16975276139138357,
#  0.06264982043070834,
#  0.09687620966986683,
#  0.15005332385522155,
#  0.02886173937932365,
#  0.07034202158027587,
#  0.049497474683058325,
#  0.0662117814289874,
#  0.09704638066409278,
#  0.05842088667591414,
#  0.039,
#  0.13360014970051495,
#  0.04600000000000001,
#  0.11512167476196654,
#  0.07831347265956223,
#  0.10008995953640906,
#  0.15000000000000002,
#  0.10012492197250394,
#  0.0524309069156733,
#  0.0828613299434664,
#  0.09618731725128839,
#  0.06711929677819933,
#  0.16122654868228126,
#  0.1376444695583517,
#  0.07421590126111789,
#  0.16975276139138357,
#  0.05011985634456668,
#  0.060406953242155836,
#  0.14705441169852743,
#  0.1281288414058287,
#  0.0841486779456457,
#  0.141718029904455,
#  0.16975276139138357,
#  0.11042191811411355,
#  0.06835202996254025,
#  0.09780081799248921,
#  0.03720215047547655,
#  0.06312685640834649,
#  0.011704699910719636,
#  0.06280127387243033,
#  0.10117806086301517,
#  0.05186520991955978,
#  0.05508175741568165,
#  0.07940403012442127,
#  0.05787054518492114,
#  0.0475184174820669,
#  0.06624198064671678,
#  0.10607544484940896,
#  0.08115417426109395,
#  0.0131529464379659,
#  0.1024158190906073,
#  0.16174362429474615,
#  0.19448650338776727,
#  0.16041508657230466,
#  0.08683317338436963,
#  0.03860051813123756,
#  0.08602325267042628,
#  0.13296616110875728,
#  0.142772546380598,
#  0.12184005909387932,
#  0.02687005768508882,
#  0.008062257748298543,
#  0.07826237921249266,
#  0.13879841497654072,
#  0.07970570870395671,
#  0.12404031602668546,
#  0.09924716620639605,
#  0.0713442359269479,
#  0.04622769732530488,
#  0.21016184239771024,
#  0.12242957159118055,
#  0.0942019108086455,
#  0.10917875251164945,
#  0.03535533905932738,
#  0.04410215414239991,
#  0.0921357693840997,
#  0.024331050121192847,
#  0.03623534186398688,
#  0.05738466694161431,
#  0.06053924347066125,
#  0.10373041983911953,
#  0.04404543109109049,
#  0.08276472678623426,
#  0.048764741360946454,
#  0.10088111815399352,
#  0.05280151512977635,
#  0.09135097153287425,
#  0.0588982172905089,
#  0.030265491900843114,
#  0.11335784048754634,
#  0.09684007434941386,
#  0.03860051813123756,
#  0.03231098884280704,
#  0.07716216689544173,
#  0.10463746938836013,
#  0.05953990258641679,
#  0.030066592756745815,
#  0.06044005294504633,
#  0.15231546211727817,
#  0.08709764635166672,
#  0.12578155667664478,
#  0.06972087205421343,
#  0.0950789145920377,
#  0.08928605714219887,
#  0.11715374513859983,
#  0.030149626863362682,
#  0.19235384061671346,
#  0.07829431652425355,
#  0.10288342918079665,
#  0.14142135623730953,
#  0.0921357693840997,
#  0.10653168542738822,
#  0.04810405388322278,
#  0.11747765745025733,
#  0.08149233092751736,
#  0.149,
#  0.09235799911215055,
#  0.08115417426109393,
#  0.05977457653551384,
#  0.07569015788066502,
#  0.140089257261219,
#  0.025495097567963934,
#  0.03901281840626233,
#  0.32609814473559956,
#  0.10688779163215975,
#  0.1496963593411677,
#  0.07200694410957878,
#  0.0582494635168428,
#  0.07947955712005447,
#  0.10383159442096612,
#  0.05921148537234986,
#  0.06000000000000001,
#  0.16975276139138357,
#  0.0967470929795826,
#  0.13790213921473443,
#  0.031890437438203946,
#  0.0331360830515618,
#  0.11629703349613005,
#  0.13727709204379296,
#  0.08115417426109393,
#  0.09585405573057408,
#  0.04609772228646445,
#  0.1885125990484456,
#  0.165,
#  0.10630145812734651,
#  0.14069825869569247,
#  0.06466065264130885,
#  0.01523154621172783,
#  0.07689603370785779,
#  0.05263078946776308,
#  0.0315753068076939,
#  0.13897481786280566,
#  0.04565084884205332,
#  0.1164989270336856,
#  0.16602710622064099,
#  0.20260552805883655,
#  0.0427551166528639,
#  0.009219544457292886,
#  0.11374093370462546,
#  0.12126417442921879,
#  0.01081665382639197,
#  0.17201162751395616,
#  0.08249242389456138,
#  0.10923827168167759,
#  0.05600892785976179,
#  0.07707788269017254,
#  0.1496161755960899,
#  0.031384709652950434,
#  0.024041630560342624,
#  0.09073588044428733,
#  0.08602325267042626,
#  0.10824047302187846,
#  0.080156097709407,
#  0.020223748416156675,
#  0.14464093473149292,
#  0.04031128874149275,
#  0.06826419266350406,
#  0.02707397274136178,
#  0.13170041761513132,
#  0.11063453348751465,
#  0.07723341245859854,
#  0.13607718398026908,
#  0.07,
#  0.1863571839237758,
#  0.14200352108310554,
#  0.06920260110718383,
#  0.08203657720797472,
#  0.1269212354178764,
#  0.08221921916437787,
#  0.07119691004531026,
#  0.04356604182158394,
#  0.024413111231467426,
#  0.04527692569068709,
#  0.17846288129468268,
#  0.10594810050208546,
#  0.11884864324004714,
#  0.10394710193170369,
#  0.10309219175087898,
#  0.05246903848937963,
#  0.11078808600206072,
#  0.10948059188732953,
#  0.12473972903610142,
#  0.10022474744293448,
#  0.09617692030835674,
#  0.08178630692236936,
#  0.08477027781009096,
#  0.08022468448052633,
#  0.05440588203494178,
#  0.10519030373565806,
#  0.04491102314577125,
#  0.04539823785126468,
#  0.07702596964660686,
#  0.08360023923410748,
#  0.09408506789071261,
#  0.10252804494381038,
#  0.09732420048477151,
#  0.10965856099730656,
#  0.06296824596572465,
#  0.0551724568965349,
#  0.13061393493804557,
#  0.08438009243891596,
#  0.030232432915661956,
#  0.09095603333479314,
#  0.14506550244630873,
#  0.027784887978899626,
#  0.037363083384538816,
#  0.08409518416651457,
#  0.030886890422961017,
#  0.20365166338628318,
#  0.055901699437494755,
#  0.09602083107326242,
#  0.3175295261861486,
#  0.10870602559196063,
#  0.06462971452822612,
#  0.139645980966156,
#  0.09400531899844818,
#  0.025179356624028353,
#  0.05445181356024795,
#  0.15005332385522155,
#  0.029427877939124335,
#  0.0674240313241503,
#  0.03891015291668742,
#  0.06573431371817919,
#  0.07559100475585705,
#  0.10822661410207751,
#  0.05024937810560447,
#  0.07723341245859851,
#  0.06280127387243034,
#  0.06447480127925949,
#  0.14317821063276354,
#  0.06606814663663572,
#  0.10207840124139878,
#  0.06896375859826669,
#  0.17889102828258327,
#  0.04604345773288535,
#  0.08621484790916238,
#  0.07441102068914256,
#  0.06280127387243034,
#  0.040706264874095247,
#  0.09732420048477151,
#  0.05860034129593443,
#  0.12140016474453401,
#  0.043931765272977596,
#  0.06463745044476926,
#  0.09394147114027969,
#  0.09121951545584969,
#  0.0766550715869472,
#  0.04827007354458868,
#  0.0607289058027559,
#  0.10124228365658294,
#  0.14362799170078233,
#  0.06711929677819933,
#  0.053009433122794304,
#  0.1071540946487814,
#  0.06177378084592202,
#  0.09394147114027969,
#  0.0872811548961172,
#  0.017117242768623687,
#  0.07783315488916019,
#  0.035383612025908256,
#  0.0651920240520265,
#  0.16975276139138357,
#  0.10480935072788117,
#  0.060605280298007054,
#  0.06044005294504633,
#  0.09884331034521256,
#  0.024999999999999988,
#  0.05135172830587106,
#  0.13080137613954987,
#  0.06198386886924696,
#  0.09362157870918436,
#  0.05247856705360772,
#  0.03061045573002791,
#  0.02720294101747087,
#  0.13101526628603252,
#  0.10897706180660224,
#  0.05842088667591414,
#  0.030413812651491103,
#  0.04140048308896891,
#  0.1890211628363343,
#  0.11545128842936316,
#  0.11205802068571442,
#  0.0360555127546399,
#  0.11187939935484104,
#  0.06236184731067546,
#  0.11141364368873322,
#  0.04808326112068523,
#  0.04827007354458868,
#  0.12601587201618691,
#  0.05780138406647371,
#  0.059413803110051795,
#  0.08052949770115297,
#  0.06020797289396149,
#  0.02751363298439522,
#  0.10771258050942796,
#  0.016124515496597113,
#  0.0949210198006743,
#  0.0831925477431723,
#  0.07433034373659253,
#  0.0906697303403953,
#  0.029966648127543384,
#  0.12860015552090132,
#  0.10478549517943789,
#  0.040804411526206334,
#  0.12202458768625281,
#  0.07043436661176133,
#  0.1329661611087573,
#  0.15074813431681336,
#  0.0272029410174709,
#  0.05721887800367988,
#  0.06185466837676846,
#  0.10519030373565808,
#  0.1303572015655445,
#  0.08429116205154609,
#  0.08417244204607587,
#  0.09740636529508738,
#  0.061032778078668526,
#  0.1380326048439281,
#  0.03324154027718933,
#  0.07488658090739624,
#  0.09386160024205853,
#  0.1286001555209013,
#  0.02061552812808829,
#  0.04837354648979129,
#  0.04428317965096907,
#  0.13865424623862047,
#  0.1246795893480565,
#  0.05500909015790027,
#  0.10568348972285124,
#  0.05813776741499453,
#  0.15231546211727817,
#  0.09518928511129812,
#  0.10694391053257779,
#  0.04205948168962619,
#  0.09708243919473801,
#  0.17500000000000002,
#  0.078873316146844,
#  0.01615549442140352,
#  0.029068883707497255,
#  0.0304138126514911,
#  0.10928860873851401,
#  0.263410326297205,
#  0.08653323061113576,
#  0.09751410154434076,
#  0.022203603311174522,
#  0.07212489168102787,
#  0.12551493934986385,
#  0.044922154890432414,
#  0.15171354586852157,
#  0.02545584412271572,
#  0.05308483775994801,
#  0.17482848738120454,
#  0.07902531240052135,
#  0.07111258679024411,
#  0.04810405388322276,
#  0.07655716818169282,
#  0.10111874208078343,
#  0.030479501308256357,
#  0.09904544411531509,
#  0.19173158320944414,
#  0.06080296045424106,
#  0.08300602387778855,
#  0.09455686120002081,
#  0.06648308055437867,
#  0.0997296345125159,
#  0.0580086200490927,
#  0.13200378782444086,
#  0.028635642126552705,
#  0.022671568097509278,
#  0.01529705854077836,
#  0.06795586803212804,
#  0.07566372975210779,
#  0.08792041856133308,
#  0.046065171225124095,
#  0.017804493814764854,
#  0.061032778078668526,
#  0.11182575731914361,
#  0.027073972741361776,
#  0.12061509026651683,
#  0.1056882207249228,
#  0.10248902380255166,
#  0.07025667228100119,
#  0.014422205101855958,
#  0.06926037828369118,
#  0.008944271909999154,
#  0.04404543109109049,
#  0.18762729012593024,
#  0.07500666637039671,
#  0.09924716620639605,
#  0.052153619241621194,
#  0.03478505426185219,
#  0.021023796041628642,
#  0.08472307831990056,
#  0.13298120167903432,
#  0.10001999800039992,
#  0.08839117603018981,
#  0.11237882362794155,
#  0.030675723300355926,
#  0.07433034373659253,
#  0.0764198926981712,
#  0.142772546380598,
#  0.09265527507918803,
#  0.13720058308914,
#  0.05331041174104737,
#  0.07045565981523415,
#  0.08420213774008355,
#  0.0327566787083184,
#  0.07783315488916019,
#  0.052886671288709414,
#  0.04346262762420147,
#  0.10184301645179213,
#  0.023600847442411903,
#  0.11910499569707395,
#  0.010770329614268992,
#  0.13476646467129721,
#  0.17452220489095363,
#  0.10242070103255495,
#  0.10155294185792947,
#  0.056859475903318,
#  0.10042410069301094,
#  0.07937883848986454,
#  0.1616044553841261,
#  0.054589376255824745,
#  0.16492422502470644,
#  0.0322490309931942,
#  0.09454099639838794,
#  0.08381527307120107,
#  0.09749871794028885,
#  0.024083189157584603,
#  0.05547071299343466,
#  0.09847842403288146,
#  0.054571054598569,
#  0.0478539444560216,
#  0.07648529270389179,
#  0.07720103626247514,
#  0.025612496949731407,
#  0.08906739021662194,
#  0.11601724009818541,
#  0.1,
#  0.07399999999999998,
#  0.06972087205421343,
#  0.19815650380444244,
#  0.06640030120413613,
#  0.16975276139138357,
#  0.04140048308896892,
#  0.07353910524340095,
#  0.050447993022517734,
#  0.13132021931142213,
#  0.031320919526731654,
#  0.06646803743153547,
#  0.09879271228182775,
#  0.14993665329064806,
#  0.14782760229402356,
#  0.08234682750416072,
#  0.12277214667830813,
#  0.1658945448168806,
#  0.02500000000000002,
#  0.046043457732885366,
#  0.12211879462228573,
#  0.11063905277974861,
#  0.10040916292848974,
#  0.10218121158021175,
#  0.113718951806636,
#  0.04332435804486895,
#  0.09518928511129812,
#  0.04272001872658767,
#  0.11881077392223316,
#  0.15559562975867927,
#  0.14153444810363305,
#  0.10478549517943789,
#  0.10824509226750192,
#  0.0468187996428785,
#  0.2161342175593675,
#  0.0744311762637136,
#  0.1120714058089752,
#  0.11049434374663711,
#  0.044181444068749055,
#  0.1338095661752178,
#  0.12206555615733705,
#  0.047707441767506256,
#  0.14001428498549712,
#  0.12976902558006667,
#  0.12120231020900551,
#  0.05481788029466297,
#  0.09079647570252934,
#  0.03373425558686602,
#  0.07922752047110904,
#  0.10868302535354821,
#  0.049203658400570185,
#  0.06395310782127794,
#  0.14412494579357174,
#  0.03828837943815329,
#  0.08472307831990053,
#  0.040521599178709636,
#  0.1,
#  0.11799152511939151,
#  0.09503683496413379,
#  0.11882760622010359,
#  0.0420119030752,
#  0.05000999900019997,
#  0.06545991139621257,
#  0.08702298546935745,
#  0.15882380174268593,
#  0.06648308055437865,
#  0.009000000000000008,
#  0.10347946656221223,
#  0.05803447251418764,
#  0.04468780594300867,
#  0.0010000000000000009,
#  0.034058772731852816,
#  0.13717871555019023,
#  0.08825531145489204,
#  0.08486459803710851,
#  0.08792041856133308,
#  0.10183319694480775,
#  0.05798275605729689,
#  0.0890224690738243,
#  0.21077001684300353,
#  0.06229767250869009,
#  0.05360037313302961,
#  0.11428473213863698,
#  0.08438009243891596,
#  0.14021768789992226,
#  0.09069729874698586,
#  0.09381364506296513,
#  0.04554119014694279,
#  0.14560219778561037,
#  0.07324616030891996,
#  0.12330855606972291,
#  0.073348483283569,
#  0.09687620966986683,
#  0.09202716990106782,
#  0.09841239759298623,
#  0.08544588931013593,
#  0.07217340230306453,
#  0.08200609733428361,
#  0.07200694410957878,
#  0.08417244204607588,
#  0.14001428498549712,
#  0.12557467897629682,
#  0.10778218776773833,
#  0.07025667228100119,
#  0.1752055935180153,
#  0.11332254850646452,
#  0.06220128616033594,
#  0.09732933781753579,
#  0.04522167621838005,
#  0.11542096863222037,
#  0.049979995998399196,
#  0.05442425929675112,
#  0.11035397591387454,
#  0.09908582138732061,
#  0.06529931086925804,
#  0.033241540277189334,
#  0.2133565091577944,
#  0.05503635162326807,
#  0.053150729063673255,
#  0.08854377448471464,
#  0.12453112060846479,
#  0.06649060083951713,
#  0.06723094525588647,
#  0.060827625302982205,
#  0.27440116617828,
#  0.04924428900898051,
#  0.06500000000000002,
#  0.09786214794290998,
#  0.08709190547921201,
#  0.10534229919647663,
#  0.07234638899074369,
#  0.09353608929178085,
#  0.08609297300012356,
#  0.044204072210600666,
#  0.13713132391981053,
#  0.20012246250733576,
#  0.04167733196834942,
#  0.030413812651491106,
#  0.034058772731852774,
#  0.14798986451781085,
#  0.14406942770761605,
#  0.11672617529928754,
#  0.05813776741499454,
#  0.14,
#  0.08602325267042626,
#  0.012369316876852986,
#  0.010816653826391954,
#  0.025179356624028357,
#  0.12713772060250256,
#  0.004242640687119309,
#  0.11469088891450796,
#  0.17844326829555662,
#  0.06621933252457324,
#  0.07343023900274329,
#  0.07427651041883969,
#  0.08635392289873112,
#  0.045880278987817866,
#  0.025,
#  0.010000000000000009,
#  0.06087692502089767,
#  0.11621101496846158,
#  0.13041855696180663,
#  0.10870602559196063,
#  0.10519030373565808,
#  0.09889893831583838,
#  0.06964194138592061,
#  0.06363961030678929,
#  0.09476286192385708,
#  0.05643580423808986,
#  0.07244308110509931,
#  0.0857088093488645,
#  0.16975276139138357,
#  0.11601724009818543,
#  0.10387011119662866,
#  0.034365680554879166,
#  0.1136001760562016,
#  0.07441102068914256,
#  0.0986154146165801,
#  0.09308598175880191,
#  0.21914607000811126,
#  0.10261578825892244,
#  0.10651291001564084,
#  0.09241753080449619,
#  0.006708203932499376,
#  0.1091283647820309,
#  0.08723531395025758,
#  0.0760591874792257,
#  0.07602631123499286,
#  0.11384638773364751,
#  0.13729530217745983,
#  0.09323089616645333,
#  0.17100292395160965,
#  0.08276472678623426,
#  0.008544003745317549,
#  0.035057096285916224,
#  0.06887670143089027,
#  0.20087807247183553,
#  0.08819297024139738,
#  0.1099317970379817,
#  0.06606814663663572,
#  0.0478539444560216,
#  0.12485191228010888,
#  0.07523961722390674,
#  0.07516648189186455,
#  0.12580143083447026,
#  0.07387827826905552,
#  0.11406138698087095,
#  0.046010868281309375,
#  0.07100704190430694,
#  0.08052949770115297,
#  0.02668332812825266,
#  0.10373041983911951,
#  0.08668333173107737,
#  0.06664082832618455,
#  0.06248199740725325,
#  0.14035668847618202,
#  0.053712196007983146,
#  0.052153619241621194,
#  0.05263078946776306,
#  0.08700000000000001,
#  0.020223748416156703,
#  ...]

# %%
num_movies = len(movies)
num_movies
# Out:
# 42204

# %%
def build_inverted_index(movies):
    word_set = []
    for t in movies['toks']:
        word_set+=t
    word_set = set(word_set)
    word_dict = {w: [] for w in word_set}
    for i in range(len(movies)):
        for w in set(movies['toks'][i]):
            if w in movies['toks'][i]:
                word_dict[w].append((i,movies['toks'][i].count(w)))
    return word_dict

# %%
#took long time to run, only needs to be done once
idx = build_inverted_index(movies)
np.save('inv_idx.npy', idx)

# %%
with open('inv_idx.txt', 'w') as file:
    json.dump(idx, file)

# %%
with open('inv_idx.csv', 'w', encoding='utf-8') as f: 
    l = []
    for k, v in idx.items():
        l.append('%s: %s' % (str(k), str(v)))
    f.write(', '.join(l))

# %%
with open('inv_idx.csv', 'r', encoding='utf-8') as f:
    inv_idx = {}
    l = f.read().split(',')
    for i in l:
        values = i.split(': ')
        inv_idx[values[0]] = values[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-52fe68798ba2> in <module>()
#       4     for i in l:
#       5         values = i.split(': ')
# ----> 6         inv_idx[values[0]] = values[1]
#
# IndexError: list index out of range

# %%
#inv_idx = np.load('inv_idx.npy',allow_pickle='TRUE').item()

# %%
#with open('inv_idx.pkl', 'wb') as f:
#    pickle.dump(inv_idx, f, pickle.HIGHEST_PROTOCOL)

# %%
#with open('inv_idx.txt', 'r') as file:
#    new_d = json.load(file)

# %%
def compute_idf(inv_idx, n_docs, min_df=20, max_df_ratio=0.8):
    idf = {x: math.log2(n_docs/(1+len(inv_idx[x]))) for x in inv_idx 
           if len(inv_idx[x])>=min_df and len(inv_idx[x])/n_docs<=max_df_ratio}
    return idf

# %%
idf = compute_idf(inv_idx,num_movies)

# %%
def compute_doc_norms(index, idf, n_docs):
    norms_sq = np.zeros(n_docs)
    for t in idf:
        for (doc,cnt) in index[t]:
            norms_sq[doc] += (cnt*idf[t])**2
    return np.sqrt(norms_sq)

# %%
#norms = compute_doc_norms(inv_idx, idf, num_movies)
#np.savetxt('norms.csv', norms, delimiter=',')

# %%
norms = np.loadtxt('norms.csv', delimiter=',')

# %%
def cleanjson(result):
    title = result[result.find("Title")+8:result.find("Year")-3]
    plot = result[result.find("Plot")+7:result.find("Language")-3]
    try:
        review_imdb = float(result[result.find(
        '"Internet Movie Database","Value":"')+35:result.find('Source":"Rotten Tomatoes"')-8])
    except:
        review_imdb = -1
    try:
        review_rotten = float(result[result.find(
        'Source":"Rotten Tomatoes","Value":')+35: result.find('},{"Source":"Metacritic"')-2])
    except:
        review_rotten = -1
    return [title, plot, review_imdb, review_rotten]

def response(result):
    text = result[result.find('"Response":' )+12:]
    return text.find('True') >-1

# %%
omdb_TOKEN = 'ce887dbd'
def find_movie(movie):
    title = ""
    plot = ""
    query = "http://www.omdbapi.com/?apikey=" + omdb_TOKEN + "&t=" + movie
    params = {"r": "json", "plot": "full"}
    result = requests.get(query, params)
    if response(result.text):
        json = cleanjson(result.text)
        plot = json[1]
        title = json[0]
        review_imdb = json[2]
        review_rotten = json[3]
    else:
        return "ERROR"
    return (title, plot, review_imdb, review_rotten)

# %%
def index_search(user_mov):
    movie = find_movie(user_mov)
    query = movie[1]
    #query = ''
    #if movie[0] in movie_titles:
    #    query = movies['Summary'][title_to_index[movie[0]]]
    #else:
    #    query = movie[1]
    scores = np.zeros(len(norms))
    docs = [i for i in range(len(norms))]
    q = query.lower()
    q_tokens = tokenizer(q)
    q_norm_sq = 0
    for t in set(q_tokens):
        if t in idf:
            q_norm_sq += (q_tokens.count(t)*idf[t])**2
            for (doc,cnt) in inv_idx[t]:
                scores[doc] += (q_tokens.count(t)*cnt*idf[t]**2)/norms[doc]
    q_norm = math.sqrt(q_norm_sq)
    new_scores = [score/q_norm for score in scores]
    result = sorted(tuple(zip(new_scores, docs)),reverse=True)
    return result[:10]

# %%
results = index_search('Memento')

# %%
results
# Out:
# [(0.16056939582947827, 35155),
#  (0.15718873462135707, 13330),
#  (0.15580892217745576, 37607),
#  (0.1485379138540403, 2487),
#  (0.14042652859711635, 34573),
#  (0.13924014073325508, 17758),
#  (0.13512155658997846, 15566),
#  (0.1330696150046359, 3533),
#  (0.13249725484059963, 41117),
#  (0.12548895093423626, 2898)]

# %%
def get_10(movie,results):
    ten = []
    for sim, ind in results[:10]:
        if movies['Title'][ind] != movie:
            s = movies['Title'][ind]+' (score: '+str(sim)+')'
            ten.append(s)
    return ten

# %%
get_10('Memento',results)
# Out:
# ['Frauds (score: 0.16056939582947824)',
#  'Duel in the Jungle (score: 0.15718873462135707)',
#  'The Fire Raisers (score: 0.15580892217745576)',
#  'Cover Up (score: 0.1485379138540403)',
#  "Killer's Carnival (score: 0.14042652859711635)",
#  'Perdido por perdido (score: 0.13924014073325505)',
#  'The Gentleman from Nowhere (score: 0.1351215565899785)',
#  'Spring Fever (score: 0.1330696150046359)',
#  'Adulterous Wife: Dizzy (score: 0.13249725484059963)',
#  'Zombie Girl: The Movie (score: 0.12548895093423626)']

# %%
movies['Title'][35155]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c67d541c1077> in <module>()
# ----> 1 movies['Title'][35155]
#
# NameError: name 'movies' is not defined

# %%
#id_to_index = {wikiid:i for i, wikiid in enumerate(movies['WikiID'])}
#title_to_id = {t:i for t, i in zip(movies['Title'], movies['WikiID'])}
#id_to_title = {v:k for k,v in title_to_id.items()}
#title_to_index = {t:i for i, t in enumerate(movies['Title'])}
#index_to_title = {v:k for k,v in title_to_index.items()}
#movie_titles = [t for t in movies['Title']]

# %%
doc_by_vocab = vectorizer.fit_transform([s for s in movies['Summary']]).toarray()

# %%
def get_summary(movie, data):
    wiki_id = title_to_id.get(movie)
    ind = id_to_index.get(wiki_id)
    summary = data['Summary'][ind]
    return summary

# %%
def get_sim(user_mov, other_mov):
    j = doc_by_vocab[title_to_index[other_mov]]
    result = find_movie(user_mov)
    if result[0] in movie_titles:
        i = doc_by_vocab[title_to_index[result[0]]]
    else:
        i = vectorizer.transform([result[1]]).toarray()[0]
    cosim = np.dot(i,j) / (np.linalg.norm(i)*np.linalg.norm(j))
    return cosim
